# %% [markdown]
# # Assignment-6
#
# This notebook contains the questions to test the proficiency in `Statistics`.
#
# ### Date: 1st February, 2026
#
# ### Steps to solve and upload the assignment
#
# - Download the notebook in your local machine.
# - Solve the questions in the notebook and save it.
# - Rename the file as `Assignment-06-<your_name>_<your_surname>.ipynb`. For example if your name is Dipika Chopra then name the file as `Assignment-06-Dipika_Chopra.ipynb`.
# - For numerical problems you can either solve the same using using python in the solution notebook or you can solve it on paper and upload the scan pdf copy of the solution.
# - If you are solving it on paper then name the pdf file of the scan copy of the solution as `Assignment-06-<your_name>_<your_surname>.pdf`. For example if your name is Akash Kumar then name the file as `Assignment-06-Akash_Kumar.pdf`.
# - Upload the solved notebook in your github repo under the folder **Assignment-6**.
# - Upload the solved notebook and the scanned pdf copy of the solutions in the google drive location: https://drive.google.com/drive/folders/1YcMNgD9h_Kdh7-Q0no3xONNctBtzqcOJ?usp=sharing
# <h3><span style="color:red"> Deadline: 22nd February, 2026 </span></h3>

# %% [markdown]
# <h5><span style="color:blue"> <b>Instructions:</b> Please answer all the questions. For problems requiring numerical solutions, you are encouraged to write code in Python to compute the results. Show your steps and explain your reasoning. </span></h5>

# %% [markdown]
# ### Problem-1
#
# A startup company with 20 employees recorded their annual salaries (in INR Lakhs):
# `[6.5, 7.2, 8.0, 6.8, 9.5, 7.0, 15.0, 7.5, 8.2, 6.9, 7.8, 10.5, 7.1, 8.5, 6.7, 7.3, 7.9, 9.0, 8.8, 7.6]`
#
# (a) Calculate the mean, median, and mode of the salaries.
#
# (b) Determine the range, variance, and standard deviation of the salaries.
#
# (c) Calculate the Interquartile Range (IQR). What does the IQR tell you about the salary distribution?
#
# (d) Construct a box plot for the salaries. Identify any potential outliers.

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import multimode

salaries = [6.5, 7.2, 8.0, 6.8, 9.5, 7.0, 15.0, 7.5, 8.2, 6.9, 7.8, 10.5, 7.1, 8.5, 6.7, 7.3, 7.9, 9.0, 8.8, 7.6]
x = np.array(salaries, dtype=float)

mean = x.mean()
median = np.median(x)
modes = multimode(salaries)

x_sorted = np.sort(x)
data_range = x_sorted[-1] - x_sorted[0]

var_pop = x.var(ddof=0)
std_pop = x.std(ddof=0)
var_samp = x.var(ddof=1)
std_samp = x.std(ddof=1)

lower = x_sorted[:len(x_sorted)//2]
upper = x_sorted[len(x_sorted)//2:]
q1 = np.median(lower)
q3 = np.median(upper)
iqr = q3 - q1

lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr
outliers = x[(x < lower_fence) | (x > upper_fence)]

print("Salaries:", salaries)
print("\n(a) Mean:", mean)
print("(a) Median:", median)
print("(a) Mode(s):", modes if len(modes) else "No mode")

print("\n(b) Range:", data_range)
print("(b) Variance (population, ddof=0):", var_pop)
print("(b) Std Dev (population, ddof=0):", std_pop)
print("(b) Variance (sample, ddof=1):", var_samp)
print("(b) Std Dev (sample, ddof=1):", std_samp)

print("\n(c) Q1:", q1)
print("(c) Q3:", q3)
print("(c) IQR:", iqr)
print("(c) IQR meaning: middle 50% of salaries lie between 7.05 and 8.65")

print("\n(d) Lower fence:", lower_fence)
print("(d) Upper fence:", upper_fence)
print("(d) Potential outliers:", outliers.tolist() if outliers.size else [])

plt.figure(figsize=(7,4))
plt.boxplot(x, vert=False, showmeans=True)
plt.title("Box Plot of Salaries (INR Lakhs)")
plt.xlabel("Salary (INR Lakhs)")
plt.show()
# Out:
# Salaries: [6.5, 7.2, 8.0, 6.8, 9.5, 7.0, 15.0, 7.5, 8.2, 6.9, 7.8, 10.5, 7.1, 8.5, 6.7, 7.3, 7.9, 9.0, 8.8, 7.6]
#
# (a) Mean: 8.190000000000001
# (a) Median: 7.699999999999999
# (a) Mode(s): [6.5, 7.2, 8.0, 6.8, 9.5, 7.0, 15.0, 7.5, 8.2, 6.9, 7.8, 10.5, 7.1, 8.5, 6.7, 7.3, 7.9, 9.0, 8.8, 7.6]
#
# (b) Range: 8.5
# (b) Variance (population, ddof=0): 3.4349000000000003
# (b) Std Dev (population, ddof=0): 1.8533483212823219
# (b) Variance (sample, ddof=1): 3.6156842105263163
# (b) Std Dev (sample, ddof=1): 1.9014952565090233
#
# (c) Q1: 7.05
# (c) Q3: 8.65
# (c) IQR: 1.6000000000000005
# (c) IQR meaning: middle 50% of salaries lie between 7.05 and 8.65
#
# (d) Lower fence: 4.649999999999999
# (d) Upper fence: 11.05
# (d) Potential outliers: [15.0]

# %% [markdown]
# ### Problem-2
#
# A tech company conducted a customer satisfaction survey, rating their latest product on a scale of 1 to 10 (10 being highly satisfied). The scores from 30 randomly selected customers are:
# [7, 8, 9, 6, 7, 8, 10, 5, 7, 8, 9, 7, 6, 8, 7, 9, 10, 6, 7, 8, 5, 9, 8, 7, 6, 7, 8, 9, 7, 8]
#
# (a) Create a frequency distribution table for these scores.
#
# (b) Plot a histogram of the customer satisfaction scores. Describe the shape of the distribution (e.g., symmetric, skewed).
#
# (c) Calculate the Pearson's (first and second) coefficients of skewness for this data. Interpret the values.
#
# (d) Calculate the excess kurtosis for this data using sample kurtosis formula. What does the kurtosis value suggest about the tails of the distribution?

# %%
from collections import Counter

scores = [7, 8, 9, 6, 7, 8, 10, 5, 7, 8, 9, 7, 6, 8, 7, 9, 10, 6, 7, 8, 5, 9, 8, 7, 6, 7, 8, 9, 7, 8]
x = np.array(scores, dtype=float)

freq = Counter(scores)
print("Frequency Distribution:")
for k in sorted(freq):
    print(f"Score {k}: {freq[k]}")

plt.figure()
plt.hist(x, bins=range(5,12), align='left', rwidth=0.8)
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.title("Histogram of Customer Satisfaction Scores")
plt.xticks(range(5,11))
plt.show()

mean = x.mean()
median = np.median(x)
std = x.std(ddof=1)
mode = max(freq, key=freq.get)

pearson_first = (mean - mode) / std
pearson_second = 3 * (mean - median) / std

n = len(x)
m4 = np.sum((x - mean)**4) / n
s2 = np.var(x, ddof=1)
sample_kurtosis = (n*(n+1)/((n-1)*(n-2)*(n-3))) * np.sum((x-mean)**4)/(s2**2) - (3*(n-1)**2/((n-2)*(n-3)))

print("\nMean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Std Dev (sample):", std)

print("\nPearson First Skewness:", pearson_first)
print("Pearson Second Skewness:", pearson_second)

print("\nExcess Kurtosis (sample):", sample_kurtosis)
# Out:
# Frequency Distribution:
# Score 5: 2
# Score 6: 4
# Score 7: 9
# Score 8: 8
# Score 9: 5
# Score 10: 2
# Mean: 7.533333333333333
# Median: 7.5
# Mode: 7
# Std Dev (sample): 1.3060425438846859
#
# Pearson First Skewness: 0.40835831560814967
# Pearson Second Skewness: 0.0765671841765278
#
# Excess Kurtosis (sample): -0.3810534029000925

# %% [markdown]
# ### Problem-3
#
# A marketing team wants to understand the relationship between their monthly advertising expenditure (in INR Lakhs) and corresponding sales revenue (in INR Lakhs) over the last 10 months.
#
# | Month | Advertising Spend (X) | Sales Revenue (Y) |
# |-------|-----------------------|-------------------|
# |     1 |                     5 |                52 |
# |     2 |                     7 |                65 |
# |     3 |                     6 |                60 |
# |     4 |                     8 |                70 |
# |     5 |                     5 |                55 |
# |     6 |                     9 |                75 |
# |     7 |                     7 |                68 |
# |     8 |                    10 |                80 |
# |     9 |                     6 |                58 |
# |    10 |                     8 |                72 |
#
#
# (a) Calculate the covariance between advertising spend and sales revenue.
#
# (b) Plot Sales Revenue vs Advertising spent.
#
# (c) Calculate the Pearson correlation coefficient between advertising spend and sales revenue.
#
# (d) Interpret the meaning of both the covariance and the correlation coefficient in the context of this data.

# %%
X = np.array([5, 7, 6, 8, 5, 9, 7, 10, 6, 8], dtype=float)
Y = np.array([52, 65, 60, 70, 55, 75, 68, 80, 58, 72], dtype=float)

covariance = np.cov(X, Y, ddof=1)[0, 1]
correlation = np.corrcoef(X, Y)[0, 1]

print("Covariance:", covariance)
print("Pearson Correlation Coefficient:", correlation)

plt.figure()
plt.scatter(X, Y)
plt.xlabel("Advertising Spend (INR Lakhs)")
plt.ylabel("Sales Revenue (INR Lakhs)")
plt.title("Sales Revenue vs Advertising Spend")
plt.show()

if covariance > 0:
    cov_interpret = "Positive covariance indicates that higher advertising spend is associated with higher sales revenue."
else:
    cov_interpret = "Negative covariance indicates an inverse relationship."

if correlation > 0:
    corr_strength = "strong" if abs(correlation) > 0.7 else "moderate" if abs(correlation) > 0.4 else "weak"
    corr_interpret = f"There is a {corr_strength} positive linear relationship between advertising spend and sales revenue."
else:
    corr_interpret = "There is a negative linear relationship."

print("\nInterpretation:")
print(cov_interpret)
print(corr_interpret)
# Out:
# Covariance: 14.944444444444443
# Pearson Correlation Coefficient: 0.9852052295662904
# Interpretation:
# Positive covariance indicates that higher advertising spend is associated with higher sales revenue.
# There is a strong positive linear relationship between advertising spend and sales revenue.

# %% [markdown]
# ### Problem-4
#
# A traffic department claims that the average daily commute time for residents in a certain city is 45 minutes. A researcher believes this claim is too low and collects data from a random sample of 100 residents. The sample mean commute time is 48 minutes with a standard deviation of 12 minutes.
#
# (a) Formulate the null and alternative hypotheses for this scenario.
#
# (b) Construct a 95% confidence interval for the true average daily commute time.
#
# (c) Based on the confidence interval, what can you conclude about the traffic department's claim?

# %%
from scipy import stats

n = 100
sample_mean = 48
sample_std = 12
claimed_mean = 45

alpha = 0.05
df = n - 1

t_critical = stats.t.ppf(1 - alpha/2, df)
margin_of_error = t_critical * (sample_std / np.sqrt(n))

ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print("Null Hypothesis: μ = 45")
print("Alternative Hypothesis: μ > 45")

print("\n95% Confidence Interval:")
print("Lower Bound:", ci_lower)
print("Upper Bound:", ci_upper)

if claimed_mean < ci_lower or claimed_mean > ci_upper:
    print("\nConclusion: The claim of 45 minutes is not supported by the confidence interval.")
else:
    print("\nConclusion: The claim of 45 minutes lies within the confidence interval.")
# Out:
# Null Hypothesis: μ = 45
# Alternative Hypothesis: μ > 45
#
# 95% Confidence Interval:
# Lower Bound: 45.61893965818958
# Upper Bound: 50.38106034181042
#
# Conclusion: The claim of 45 minutes is not supported by the confidence interval.

# %% [markdown]
# ### Problem-5
#
# A manufacturing company wants to estimate the average number of units produced per hour by a new machine. They take 36 random observations and find the sample mean to be 150 units with a sample standard deviation of 15 units.
#
# (a) What is the point estimate for the true average number of units produced per hour?
#
# (b) Construct a 99% confidence interval for the true average number of units produced per hour.
#
# (c) If the company wants to be 99% confident that their estimate is within 3 units of the true mean, what sample size would they need (assuming the same standard deviation)?

# %%
n = 36
xbar = 150
s = 15

print("Point Estimate (mean):", xbar)

alpha = 0.01
df = n - 1
t_crit = stats.t.ppf(1 - alpha/2, df)
me = t_crit * (s / np.sqrt(n))
ci = (xbar - me, xbar + me)

print("\n99% Confidence Interval for true mean:")
print("Lower Bound:", ci[0])
print("Upper Bound:", ci[1])

E = 3
z_crit = stats.norm.ppf(1 - alpha/2)
n_required = int(np.ceil((z_crit * s / E) ** 2))

print("\nRequired sample size for 99% CI within ±3 units:")
print("n:", n_required)
# Out:
# Point Estimate (mean): 150
#
# 99% Confidence Interval for true mean:
# Lower Bound: 143.1904860269799
# Upper Bound: 156.8095139730201
#
# Required sample size for 99% CI within ±3 units:
# n: 166

# %% [markdown]
# ### Problem-6
#
# A website designer believes that a new website redesign will increase the average time users spend on the site. Before the redesign, the average time spent was 3.5 minutes. After the redesign, a random sample of 50 users showed an average time of 3.8 minutes with a standard deviation of 1.0 minute.
#
# (a) Perform a one-sided hypothesis test at a 0.05 significance level to determine if the redesign significantly increased the average time spent.
#
# (b) State your null and alternative hypotheses, calculate the test statistic, and determine the p-value.
#
# (c) What is your conclusion regarding the website redesign's impact?

# %%
mu0 = 3.5
xbar = 3.8
s = 1.0
n = 50
alpha = 0.05
df = n - 1

t_stat = (xbar - mu0) / (s / np.sqrt(n))
p_value = 1 - stats.t.cdf(t_stat, df)

print("H0: μ = 3.5")
print("H1: μ > 3.5")
print("\nTest statistic (t):", t_stat)
print("p-value (one-sided):", p_value)

if p_value < alpha:
    print("\nConclusion: Reject H0. Evidence suggests the redesign increased the average time spent on the site.")
else:
    print("\nConclusion: Fail to reject H0. Not enough evidence that the redesign increased the average time spent on the site.")
# Out:
# H0: μ = 3.5
# H1: μ > 3.5
#
# Test statistic (t): 2.1213203435596415
# p-value (one-sided): 0.01948902762217475
#
# Conclusion: Reject H0. Evidence suggests the redesign increased the average time spent on the site.

# %% [markdown]
# ### Problem-7
#
# A company implemented a new training program to improve employee productivity. To assess its effectiveness, 15 employees' productivity scores were recorded before and after the training program. The scores are as follows:
#
# | Employee | Before Training | After Training |
# |----------|-----------------|----------------|
# |        1 |              65 |             70 |
# |        2 |              70 |             72 |
# |        3 |              60 |             68 |
# |        4 |              75 |             73 |
# |        5 |              80 |             85 |
# |        6 |              68 |             70 |
# |        7 |              72 |             75 |
# |        8 |              62 |             65 |
# |        9 |              78 |             80 |
# |       10 |              70 |             72 |
# |       11 |              66 |             69 |
# |       12 |              73 |             76 |
# |       13 |              64 |             67 |
# |       14 |              71 |             74 |
# |       15 |              69 |             71 |
#
# (a) State the null and alternative hypotheses to test if the training program significantly improved productivity.
#
# (b) Conduct a paired samples t-test at a 0.05 significance level. Calculate the test statistic and the p-value.
#
# (c) Based on your analysis, did the training program effectively improve employee productivity?

# %%
before = np.array([65, 70, 60, 75, 80, 68, 72, 62, 78, 70, 66, 73, 64, 71, 69], dtype=float)
after = np.array([70, 72, 68, 73, 85, 70, 75, 65, 80, 72, 69, 76, 67, 74, 71], dtype=float)

d = after - before
n = len(d)
df = n - 1
alpha = 0.05

t_stat = d.mean() / (d.std(ddof=1) / np.sqrt(n))
p_value = 1 - stats.t.cdf(t_stat, df)

print("H0: μ_d = 0")
print("H1: μ_d > 0")

print("\nMean difference (after - before):", d.mean())
print("Std dev of differences:", d.std(ddof=1))
print("t statistic:", t_stat)
print("p-value (one-sided):", p_value)

if p_value < alpha:
    print("\nConclusion: Reject H0. Evidence suggests the training program improved productivity.")
else:
    print("\nConclusion: Fail to reject H0. Not enough evidence that the training program improved productivity.")
# Out:
# H0: μ_d = 0
# H1: μ_d > 0
#
# Mean difference (after - before): 2.933333333333333
# Std dev of differences: 2.1201976547572388
# t statistic: 5.358345304922001
# p-value (one-sided): 5.04599945823081e-05
#
# Conclusion: Reject H0. Evidence suggests the training program improved productivity.

# %% [markdown]
# ### Problem-8
#
# A battery manufacturer claims that their new 'ProLife' battery lasts longer than their existing 'Standard' battery. A consumer watchdog organization tests 40 'ProLife' batteries and 50 'Standard' batteries. The results are:
#
# ProLife: Sample mean life = 120 hours, Sample standard deviation = 10 hours
#
# Standard: Sample mean life = 115 hours, Sample standard deviation = 12 hours
#
# (a) State the null and alternative hypotheses for testing the manufacturer's claim.
#
# (b) Perform a t-test for two independent means at a 0.02 significance level.
#
# (c) What is your conclusion regarding the manufacturer's claim about the 'ProLife' battery?

# %%
n1, x1, s1 = 40, 120, 10
n2, x2, s2 = 50, 115, 12
alpha = 0.02

se = np.sqrt((s1**2)/n1 + (s2**2)/n2)
t_stat = (x1 - x2) / se

v1 = (s1**2)/n1
v2 = (s2**2)/n2
df = (v1 + v2)**2 / ((v1**2)/(n1-1) + (v2**2)/(n2-1))

p_value = 1 - stats.t.cdf(t_stat, df)

print("H0: μ_ProLife - μ_Standard = 0")
print("H1: μ_ProLife - μ_Standard > 0")
print("\nTest statistic (Welch t):", t_stat)
print("Degrees of freedom:", df)
print("p-value (one-sided):", p_value)

if p_value < alpha:
    print("\nConclusion: Reject H0. Evidence supports that ProLife lasts longer than Standard at α = 0.02.")
else:
    print("\nConclusion: Fail to reject H0. Not enough evidence that ProLife lasts longer than Standard at α = 0.02.")
# Out:
# H0: μ_ProLife - μ_Standard = 0
# H1: μ_ProLife - μ_Standard > 0
#
# Test statistic (Welch t): 2.1556530677961345
# Degrees of freedom: 87.8354340166509
# p-value (one-sided): 0.01692266085894678
#
# Conclusion: Reject H0. Evidence supports that ProLife lasts longer than Standard at α = 0.02.

# %% [markdown]
# ### Problem-9
#
# A popular restaurant chain claims that the average waiting time for a table on weekends is no more than 20 minutes. A local food critic believes it's longer. They record the waiting times (in minutes) for 30 randomly selected tables on various weekends:
#
# `[22, 25, 18, 30, 28, 20, 23, 26, 19, 32, 21, 24, 27, 29, 20, 25, 23, 17, 31, 26, 22, 28, 20, 24, 27, 29, 21, 23, 25, 26]`
#
# (a) Calculate the sample mean and sample standard deviation of the waiting times.
#
# (b) Conduct a one-sided t-test at a 0.01 significance level to assess the food critic's belief.
#
# (c) State your null and alternative hypotheses, calculate the test statistic, and determine the critical value.
#
# (d) Based on your findings, what can you tell the food critic?

# %%
wait_times = [22, 25, 18, 30, 28, 20, 23, 26, 19, 32, 21, 24, 27, 29, 20, 25, 23, 17, 31, 26, 22, 28, 20, 24, 27, 29, 21, 23, 25, 26]
x = np.array(wait_times, dtype=float)

mu0 = 20
alpha = 0.01
n = len(x)
df = n - 1

xbar = x.mean()
s = x.std(ddof=1)

t_stat = (xbar - mu0) / (s / np.sqrt(n))
critical_value = stats.t.ppf(1 - alpha, df)
p_value = 1 - stats.t.cdf(t_stat, df)

print("Sample mean:", xbar)
print("Sample std dev:", s)

print("\nH0: μ ≤ 20")
print("H1: μ > 20")

print("\nTest statistic (t):", t_stat)
print("Critical value (right-tailed, α=0.01):", critical_value)
print("p-value (one-sided):", p_value)

if t_stat > critical_value:
    print("\nDecision: Reject H0")
    print("Conclusion: There is sufficient evidence at α=0.01 that the average weekend waiting time is greater than 20 minutes.")
else:
    print("\nDecision: Fail to reject H0")
    print("Conclusion: There is not sufficient evidence at α=0.01 that the average weekend waiting time is greater than 20 minutes.")
# Out:
# Sample mean: 24.366666666666667
# Sample std dev: 3.925893997315888
#
# H0: μ ≤ 20
# H1: μ > 20
#
# Test statistic (t): 6.0921711999214265
# Critical value (right-tailed, α=0.01): 2.4620213601503833
# p-value (one-sided): 6.186435673738444e-07
#
# Decision: Reject H0
# Conclusion: There is sufficient evidence at α=0.01 that the average weekend waiting time is greater than 20 minutes.

# %% [markdown]
# ### Problem-10
#
# A software company is launching a new application and offers three different subscription tiers (Basic, Premium, Elite), each with varying features. Before the full launch, they conduct a pilot study to see if there's an association between a customer's age group and their preferred subscription tier. They surveyed 300 randomly selected potential customers and recorded their age group and preferred tier:
#
# | Age Group   | Basic | Premium | Elite | Total |
# |-------------|-------|---------|-------|-------|
# | 18-29 years |    45 |      60 | 15    | 120   |
# | 30-49 years |    30 |      50 | 20    | 100   |
# |   50+ years |    25 |      40 | 15    | 80    |
# |       Total |   100 |     150 | 50    | 300   |
#
#
# (a) State the null and alternative hypotheses for the test of independence in this context.
#
# (b) Calculate the expected frequencies for each cell in the table, assuming the null hypothesis is true. Show your calculations clearly.
#
# (c) Calculate the chi-square test statistic.
#
# (d) Using a significance level of α=0.05, determine the critical value for this test.
#
# (e) What is your conclusion? Is there a significant association between a customer's age group and their preferred subscription tier? Justify your answer based on your calculated chi-square statistic and the critical value.

# %%
observed = np.array([
    [45, 60, 15],
    [30, 50, 20],
    [25, 40, 15]
], dtype=float)

row_totals = observed.sum(axis=1, keepdims=True)
col_totals = observed.sum(axis=0, keepdims=True)
grand_total = observed.sum()

expected = row_totals @ col_totals / grand_total
chi_square = ((observed - expected) ** 2 / expected).sum()

r, c = observed.shape
df = (r - 1) * (c - 1)
alpha = 0.05
critical_value = stats.chi2.ppf(1 - alpha, df)
p_value = 1 - stats.chi2.cdf(chi_square, df)

print("H0: Age group and preferred subscription tier are independent.")
print("H1: Age group and preferred subscription tier are associated (not independent).")

print("\nObserved Frequencies:\n", observed.astype(int))
print("\nExpected Frequencies:\n", expected)

print("\nChi-square test statistic:", chi_square)
print("Degrees of freedom:", df)
print("Critical value (alpha=0.05):", critical_value)
print("p-value:", p_value)

if chi_square > critical_value:
    print("\nDecision: Reject H0")
    print("Conclusion: There is a significant association between age group and preferred subscription tier at α=0.05.")
else:
    print("\nDecision: Fail to reject H0")
    print("Conclusion: There is no significant association between age group and preferred subscription tier at α=0.05.")
# Out:
# H0: Age group and preferred subscription tier are independent.
# H1: Age group and preferred subscription tier are associated (not independent).
#
# Observed Frequencies:
#  [[45 60 15]
#  [30 50 20]
#  [25 40 15]]
#
# Expected Frequencies:
#  [[40.         60.         20.        ]
#  [33.33333333 50.         16.66666667]
#  [26.66666667 40.         13.33333333]]
#
# Chi-square test statistic: 3.1875
# Degrees of freedom: 4
# Critical value (alpha=0.05): 9.487729036781154
# p-value: 0.5269522746367854
#
# Decision: Fail to reject H0
# Conclusion: There is no significant association between age group and preferred subscription tier at α=0.05.

# %% [markdown]
# ### Bonus Problem
#
# An e-commerce company is testing two different designs for its product pages (Design A and Design B) to see if one leads to significantly higher conversion rates (percentage of visitors who make a purchase). They randomly assigned 50,000 website visitors to see Design A and another 50,000 visitors to see Design B over a two-week period. At the end of the period, they collected data on the conversion rates. Due to data collection specifics, they have daily average conversion rates for 30 randomly selected days for each design, rather than individual visitor data.
#
# Here are the summary statistics for the daily average conversion rates (in percentage points):
#
# * Design A (Sample 1):
#
#     - Number of days ($n_A$) = 30
#     - Mean Daily Conversion Rate ($\bar{x}_A$) = 2.85%
#     - Sample Standard Deviation ($s_A$) = 0.45%
#
# * Design B (Sample 2):
#
#     - Number of days ($n_B$) = 30
#     - Mean Daily Conversion Rate ($\bar{x}_B$) = 3.05%
#     - Sample Standard Deviation ($s_B$) = 0.60%
#
# The company is concerned that the variability in conversion rates might differ between the two designs due to different aesthetic elements or backend processes.
#
# (a) State the null and alternative hypotheses to test if there is a significant difference in the average daily conversion rates between Design A and Design B. (Consider a two-tailed test, as they are looking for any significant difference).
#
# (b) Before performing the t-test, you need to decide whether to assume equal or unequal population variances. For the purpose of this problem, assume that a prior test suggests equal population variances.
#
# (c) Calculate the appropriate test statistic (t-value) for comparing the two independent means, assuming equal population variances. Show all steps of your calculation.
#
# (d) Determine the degrees of freedom for this test.
#
# (e) Using a significance level of α=0.05, determine the critical value(s) for your test.
#
# (f) Based on your calculated test statistic and the critical value(s), what is your conclusion? Is there a statistically significant difference in the average daily conversion rates between Design A and Design B?
#
# (g) Construct a 95% confidence interval for the difference between the true mean daily conversion rates $(μ_B - μ_A)$. Interpret this interval in the context of the problem.
#
# (h) Show all the steps when a prior test suggests unequal population variances.

# %%
nA, meanA, sA = 30, 2.85, 0.45
nB, meanB, sB = 30, 3.05, 0.60
alpha = 0.05

diff = meanB - meanA

sp2 = ((nA - 1) * sA**2 + (nB - 1) * sB**2) / (nA + nB - 2)
sp = np.sqrt(sp2)
SE_pooled = sp * np.sqrt(1/nA + 1/nB)
t_pooled = diff / SE_pooled
df_pooled = nA + nB - 2
tcrit_two = stats.t.ppf(1 - alpha/2, df_pooled)
p_two = 2 * (1 - stats.t.cdf(abs(t_pooled), df_pooled))
ci_pooled = (diff - tcrit_two * SE_pooled, diff + tcrit_two * SE_pooled)

SE_welch = np.sqrt(sA**2/nA + sB**2/nB)
t_welch = diff / SE_welch
vA = sA**2 / nA
vB = sB**2 / nB
df_welch = (vA + vB)**2 / ((vA**2)/(nA - 1) + (vB**2)/(nB - 1))
tcrit_welch = stats.t.ppf(1 - alpha/2, df_welch)
p_two_welch = 2 * (1 - stats.t.cdf(abs(t_welch), df_welch))
ci_welch = (diff - tcrit_welch * SE_welch, diff + tcrit_welch * SE_welch)

print("H0: μA = μB")
print("H1: μA ≠ μB")

print("\nGiven:")
print("nA =", nA, "meanA =", meanA, "sA =", sA)
print("nB =", nB, "meanB =", meanB, "sB =", sB)
print("Difference (μB - μA) estimate =", diff)

print("\nEqual variances (pooled) t-test:")
print("sp^2 =", sp2)
print("sp =", sp)
print("SE =", SE_pooled)
print("t statistic =", t_pooled)
print("df =", df_pooled)
print("critical values (α=0.05, two-tailed) =", (-tcrit_two, tcrit_two))
print("p-value (two-tailed) =", p_two)

if p_two < alpha:
    print("Conclusion: Reject H0. There is a statistically significant difference between Design A and Design B.")
else:
    print("Conclusion: Fail to reject H0. No statistically significant difference between Design A and Design B.")

print("\n95% CI for (μB - μA) assuming equal variances:", ci_pooled)

print("\nUnequal variances (Welch) steps:")
print("SE_welch =", SE_welch)
print("t_welch =", t_welch)
print("df_welch =", df_welch)
print("critical values (α=0.05, two-tailed) =", (-tcrit_welch, tcrit_welch))
print("p-value (two-tailed) =", p_two_welch)
print("95% CI for (μB - μA) using Welch:", ci_welch)
# Out:
# H0: μA = μB
# H1: μA ≠ μB
#
# Given:
# nA = 30 meanA = 2.85 sA = 0.45
# nB = 30 meanB = 3.05 sB = 0.6
# Difference (μB - μA) estimate = 0.19999999999999973
#
# Equal variances (pooled) t-test:
# sp^2 = 0.28125
# sp = 0.5303300858899106
# SE = 0.1369306393762915
# t statistic = 1.4605934866804415
# df = 58
# critical values (α=0.05, two-tailed) = (np.float64(-2.0017174841452356), np.float64(2.0017174841452356))
# p-value (two-tailed) = 0.14952322460034284
# Conclusion: Fail to reject H0. No statistically significant difference between Design A and Design B.
#
# 95% CI for (μB - μA) assuming equal variances: (np.float64(-0.07409645495470901), np.float64(0.4740964549547085))
#
# Unequal variances (Welch) steps:
# SE_welch = 0.13693063937629155
# t_welch = 1.4605934866804409
# df_welch = 53.78338278931752
# critical values (α=0.05, two-tailed) = (np.float64(-2.005064236429221), np.float64(2.005064236429221))
# p-value (two-tailed) = 0.14994452630949362
# 95% CI for (μB - μA) using Welch: (np.float64(-0.07455472788478928), np.float64(0.47455472788478875))
